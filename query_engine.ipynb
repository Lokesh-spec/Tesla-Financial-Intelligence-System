# %%
import os
from dotenv import load_dotenv
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("API Key is set.")
# Out:
# API Key is set.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-5-nano', temperature=0)

# %%
from langchain_openai import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model='text-embedding-3-small', dimensions=1024)

# %%
from langchain_chroma import Chroma

# %%
vectorstore_persist = Chroma(
    persist_directory='/Users/lokeshkv/data-engineering/Tesla_Financial_Document_Q_and_A_System_using_RAG/data/vector_db_path',
    embedding_function=embedding_model
)

# %%
# Pass the query string as the first parameter or specify it by name
results = vectorstore_persist.similarity_search(
    query="What were Tesla’s total revenues in 2017?",
    k=5,
)

# %%
for r in results:
    print(r.metadata)
    print(r.page_content[:300])
    print("-----")
# Out:
# {'chunk_id': 'chunk_593', 'source': 'tsla-20231231-gen.txt'}
# consolidated financial statements. 49 --- Page 51 --- Tesla, Inc. Consolidated Statements of Operations (in millions, except per share data) Year Ended December 31, 2023 2022 2021 Revenues Automotive sales $ 78,509 $ 67,210 $ 44,125 Automotive regulatory credits 1,790 1,776 1,465 Automotive leasing
# -----
# {'source': 'NASDAQ_TSLA_2022.txt', 'chunk_id': 'chunk_597'}
# part of these consolidated financial statements. 48 --- Page 49 --- Tesla, Inc. Consolidated Statements of Operations (in millions, except per share data) Year Ended December 31, 2022 2021 2020 Revenues Automotive sales $ 67,210 $ 44,125 $ 24,604 Automotive regulatory credits 1,776 1,465 1,580 Autom
# -----
# {'source': 'NASDAQ_TSLA_2018.txt', 'chunk_id': 'chunk_864'}
# ...

# %%
llm.invoke("What were Tesla’s total revenues in 2017?")
# Out:
# AIMessage(content='Tesla’s total revenues in 2017 were $11.759 billion (11,759 million USD), per Tesla’s 2017 Form 10-K.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 489, 'prompt_tokens': 17, 'total_tokens': 506, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DaoA2Y139phFp2f5X1YwUCSbm7V7t', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019de517-3509-7313-8272-9e50adbd0621-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 489, 'total_tokens': 506, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})
